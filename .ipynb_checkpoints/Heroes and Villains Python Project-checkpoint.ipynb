# %%
# Data Project 2: Working with Marvel Heroes
# It’s time to work on some famous characters .We need to work on Marvel Characters data set which is having "characters_stats".csv. Following requirements are there which we need to fulfill:

# 1. Import required libraries
# 2. Read csv
# 3. Show first records from csv
# 4. Show number of rows and columns
# 5. You need to find the values of alignment ,can use value_counts()
# 6. Find out only good alignment holders superheroes
# 7. Show first five records which you found in point 6
# 8. Show top five records having top speed of heroes of good alignment
# 9. Show 5 records of super heroes who have maximum power of good alignment
# 10. Find out how many super heroes are there with power 100 of good alignment
# 11. Shape them what you got in point 10
# 12. Show all records from point 10
# 13. Retrieve total of first five records of max power of good alignment super heroes
# 14. Draw a bar plot of all super heroes who are having good alignment and max power of top five only , take same object of point 13 , show name and total in plot with green bars
# 15. Extract villains having bad alignment
# 16. Show first five records of point 15
# 17. Show top five fastest super villains in terms of super speed
# 18. Top five super villains in terms of intelligence
# 19. Show who is most dangerous super villain after calculating their total (top 5 only)
# 20. Draw a histogram for speed of super heroes having fig size 10,5 , provide speed in histogram for only good alignment super heroes ,title should be "distribution of speed" , xlabel should be "speed"
# 21. Draw a histogram for combat of super villains having fig size 10,5 , provide combat in histogram for only bad alignment super heroes ,title should be "distribution of combat" , xlabel should be "combat"

# *** Explain how you retrieve data with the help of comments in almost each section.

# Bonus: Can go beyond the scope and extract some different information on different characters and their properties. Can draw some more plots and histograms.

# %%
# 1. Import required libraries

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# 2. Read csv

df = pd.read_csv('characters_stats.csv')

# %%
# 3. Show first records from csv

df.head()                                # head() reveals first 5 records by default
# Out:
#           Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 0      3-D Man      good            50        31     43          32     25
# 1       A-Bomb      good            38       100     17          80     17
# 2   Abe Sapien      good            88        14     35          42     35
# 3     Abin Sur      good            50        90     53          64     84
# 4  Abomination       bad            63        80     53          90     55
#
#    Combat  Total
# 0      52    233
# 1      64    316
# 2      85    299
# 3      65    406
# 4      95    436

# %%
# 4. Show number of rows and columns

row_size = len(df)
column_size = len(df.columns)
print('Number of Rows:', row_size)
print('Number of Columns:', column_size)
# Out:
# Number of Rows: 611
# Number of Columns: 9

# %%
# 5. You need to find the values of alignment, can use value_counts()

df['Alignment'].value_counts()
# Out:
# good       432
# bad        165
# neutral     11
# Name: Alignment, dtype: int64

# %%
# 6. Find out only good alignment holders superheroes

good_superheroes = df[df['Alignment'] == 'good']
good_superheroes
# Out:
#                   Name Alignment  Intelligence  Strength  Speed  Durability  \
# 0              3-D Man      good            50        31     43          32
# 1               A-Bomb      good            38       100     17          80
# 2           Abe Sapien      good            88        14     35          42
# 3             Abin Sur      good            50        90     53          64
# 6          Adam Monroe      good            63        10     12         100
# 7         Adam Strange      good             1         1      1           1
# 8            Agent  13      good             1         1      1           1
# 9            Agent Bob      good            10         8     13           5
# 10          Agent Zero      good            75        28     38          80
# 12          Alan Scott      good            63        80     23          90
# 13        Alex Woolsly      good             1         1      1           1
# 14   Alfred Pennyworth      good            63        10     17          10
# 15    Allan Quatermain      good             1         1      1           1
# 18      Ando Masahashi      good             1         1      1           1
# 19               Angel      good            63        13     46          64
# 20     Angel Salvadore      good            38        10     28          28
# 22          Animal Man      good            56        48     47          85
# 24             Ant-Man      good           100        10     23          28
# 25          Ant-Man II      good            63        10     23          28
# 30            Aquababy      good            10        16     12          14
# 31             Aqualad      good            63        44     42          75
# 32             Aquaman      good            63        80     50          80
# 33             Arachne      good             1         1      1           1
# 34           Archangel      good            63        13     58          64
# 36                Ares      good            75        82     35          80
# 37               Ariel      good            50        10     12          14
# 38               Armor      good            50        63     12          80
# 39             Arsenal      good             1         1      1           1
# 40           Astro Boy      good             1         1      1           1
# 41               Atlas      good            50        80     23          99
# ..                 ...       ...           ...       ...    ...         ...
# 573         Vertigo II      good             1         1      1           1
# 574         Vindicator      good             1         1      1           1
# 575      Vindicator II      good            63        63     53          64
# 577             Violet      good            10         4     12          28
# 578             Vision      good           100        72     54          95
# 579          Vision II      good             1         1      1           1
# 580             Vulcan      good             1         1      1           1
# 583        War Machine      good            63        80     63         100
# 584            Warbird      good             1         1      1           1
# 585            Warlock      good            88        36     79          95
# 587            Warpath      good            38        72     47          70
# 588               Wasp      good            63         8     58          52
# 589            Watcher      good           100        80     67          89
# 591        White Queen      good             1         1      1           1
# 592           Wildfire      good            50        32     23         100
# 594     Winter Soldier      good            56        32     35          65
# 595            Wiz Kid      good             1         1      1           1
# 596          Wolfsbane      good            38        16     35          42
# 597          Wolverine      good            55        32     38         100
# 598        Wonder Girl      good            75        90     25          80
# 599         Wonder Man      good            75       100     53          90
# 600       Wonder Woman      good            88       100     50         100
# 601             Wondra      good             1         1      1           1
# 602     Wyatt Wingfoot      good            10        10     12           1
# 603               X-23      good            75        24     35          90
# 604              X-Man      good            88        53     53          95
# 606       Yellowjacket      good            88        10     12          28
# 607    Yellowjacket II      good            50        10     35          28
# 608               Ymir      good            50       100     27         100
# 609            Zatanna      good            75        10     23          28
#
#      Power  Combat  Total
# 0       25      52    233
# 1       17      64    316
# 2       35      85    299
# 3       84      65    406
# 6       71      64    320
# 7        0       1      5
# 8        0       1      5
# 9        5      20     61
# 10      72      95    388
# 12      98      32    386
# 13       0       1      5
# 14       7      55    162
# 15       0       1      5
# 18       0       1      5
# 19      17      42    245
# 20      46      60    210
# 22      73      80    389
# 24      32      32    225
# 25      32      28    184
# 30      37      14    103
# 31      76      60    360
# 32      65      80    418
# 33       0       1      5
# 34      28      42    268
# 36      62     101    435
# 37      72      28    186
# 38      55      54    314
# 39       0       1      5
# 40       0       1      5
# 41      69      42    363
# ..     ...     ...    ...
# 573      0       1      5
# 574      0       1      5
# 575     56      70    369
# 577     65      14    133
# 578     76      70    467
# 579      0       1      5
# 580      0       1      5
# 583    100      85    491
# 584      0       1      5
# 585     71      95    464
# 587     26      84    337
# 588     23      42    246
# 589    100      56    492
# 591      0       1      5
# 592     77      42    324
# 594     60      84    332
# 595      0       1      5
# 596     26      42    199
# 597     44     100    369
# 598     39      60    369
# 599     64      64    446
# 600     42     100    480
# 601      0       1      5
# 602      1      56     90
# 603     27      85    336
# 604     92      84    465
# 606     12      14    164
# 607     31      28    182
# 608     83      28    388
# 609    100      56    292
#
# [432 rows x 9 columns]

# %%
# 7. Show first five records which you found in point 6

good_superheroes.head()
# Out:
#           Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 0      3-D Man      good            50        31     43          32     25
# 1       A-Bomb      good            38       100     17          80     17
# 2   Abe Sapien      good            88        14     35          42     35
# 3     Abin Sur      good            50        90     53          64     84
# 6  Adam Monroe      good            63        10     12         100     71
#
#    Combat  Total
# 0      52    233
# 1      64    316
# 2      85    299
# 3      65    406
# 6      64    320

# %%
# 8. Show top five records having top speed of heroes of good alignment

fastest_good_heroes = df[df['Alignment'] == 'good'].nlargest(5,'Speed')
fastest_good_heroes
# Out:
#            Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 85   Black Bolt      good            75        67    100          84    100
# 229     Flash I      good            63        10    100          50     57
# 230    Flash II      good            63        10    100          60     66
# 231   Flash III      good            63        10    100          60     83
# 232    Flash IV      good            63        10    100          32     59
#
#      Combat  Total
# 85       56    482
# 229      32    312
# 230      32    331
# 231      32    348
# 232      48    312

# %%
# 9. Show 5 records of super heroes who have maximum power of good alignment

most_powerful_good_heroes = df[df['Alignment'] == 'good'].nlargest(5,'Power')
most_powerful_good_heroes
# Out:
#               Name Alignment  Intelligence  Strength  Speed  Durability  \
# 69   Beta Ray Bill      good            63        80     35          95
# 70        Beyonder      good            88       100     23         100
# 85      Black Bolt      good            75        67    100          84
# 129          Cable      good            88        48     23          56
# 185        Deadman      good            50        10     33         100
#
#      Power  Combat  Total
# 69     100      84    457
# 70     100      56    467
# 85     100      56    482
# 129    100      80    395
# 185    100      42    335

# %%
# 10. Find out how many super heroes are there with power 100 of good alignment

good_heroes_with_power_100 = df[(df['Power'] == 100) & (df['Alignment'] == 'good')]
print('Number of superheroes with power 100 and good alignment: ', len(good_heroes_with_power_100))
# Out:
# Number of superheroes with power 100 and good alignment:  33

# %%
# 11. Shape them what you got in point 10

good_heroes_with_power_100.shape                # Returns dimensions of the dataframe (rows,columns)
# Out:
# (33, 9)

# %%
# 12. Show all records from point 10

good_heroes_with_power_100
# Out:
#                   Name Alignment  Intelligence  Strength  Speed  Durability  \
# 69       Beta Ray Bill      good            63        80     35          95
# 70            Beyonder      good            88       100     23         100
# 85          Black Bolt      good            75        67    100          84
# 129              Cable      good            88        48     23          56
# 185            Deadman      good            50        10     33         100
# 196        Doctor Fate      good            81        16     25          80
# 198     Doctor Strange      good           100        10     12          84
# 204       Dr Manhattan      good            88        32     42          95
# 226          Firestorm      good            50        53     58          56
# 251               Goku      good            56       100     75          90
# 266         Hal Jordan      good            63        90     53          64
# 294             Iceman      good            63        32     53         100
# 299           Iron Man      good           100        85     58          85
# 306          Jean Grey      good           100        80     67         100
# 327            Kilowog      good            81        90     53          42
# 361  Martian Manhunter      good           100       100     96         100
# 362        Marvel Girl      good            63        85     47          42
# 383       Miss Martian      good            63        85     58         100
# 408     Naruto Uzumaki      good            50        80     32          80
# 417               Nova      good           100        85     67         101
# 418               Nova      good            38        60    100         100
# 419          Offspring      good            50        10     35          99
# 433            Phoenix      good           100        80     67         100
# 435        Plastic Man      good            50        63     23         100
# 487        Shadow King      good            75        12     27         100
# 499      Silver Surfer      good            63       100     84         101
# 511              Spawn      good            75        60     50          90
# 525           Stardust      good            88        85    100         110
# 546               Thor      good            69       100     92         100
# 547          Thor Girl      good            75        83     70          84
# 583        War Machine      good            63        80     63         100
# 589            Watcher      good           100        80     67          89
# 609            Zatanna      good            75        10     23          28
#
#      Power  Combat  Total
# 69     100      84    457
# 70     100      56    467
# 85     100      56    482
# 129    100      80    395
# 185    100      42    335
# 196    100      50    352
# 198    100      60    366
# 204    100      42    399
# 226    100      42    359
# 251    100     100    521
# 266    100      56    426
# 294    100      64    412
# 299    100      64    492
# 306    100      70    517
# 327    100      80    446
# 361    100      85    581
# 362    100      80    417
# 383    100      45    451
# 408    100     100    442
# 417    100      85    538
# 418    100      25    423
# 419    100      56    350
# 433    100      70    517
# 435    100      56    392
# 487    100      75    389
# 499    100      32    480
# 511    100      95    470
# 525    100      85    568
# 546    100      85    546
# 547    100      70    482
# 583    100      85    491
# 589    100      56    492
# 609    100      56    292

# %%
# 13. Retrieve total of first five records of max power of good alignment super heroes

top_5_name_total_power_100_good_heroes = good_heroes_with_power_100[['Name', "Total"]].nlargest(5,'Total')
top_5_name_total_power_100_good_heroes
# Out:
#                   Name  Total
# 361  Martian Manhunter    581
# 525           Stardust    568
# 546               Thor    546
# 417               Nova    538
# 251               Goku    521

# %%
# 14. Draw a bar plot of all super heroes who are having good alignment and max power of top five only,
            # take same object of point 13,
            # show name and total in plot with green bar

top_5_name_total_power_100_good_heroes.plot(x='Name', y='Total', kind='bar', color='green', figsize=(10,10))

for i in range(len(top_5_name_total_power_100_good_heroes['Name'])):
  plt.text(i, top_5_name_total_power_100_good_heroes['Total'].iloc[i], top_5_name_total_power_100_good_heroes['Total'].iloc[i], ha="center", va="bottom")

# %%
# 15. Extract villains having bad alignment

villains = df[df['Alignment'] == 'bad']
villains
# Out:
#                 Name Alignment  Intelligence  Strength  Speed  Durability  \
# 4        Abomination       bad            63        80     53          90
# 5            Abraxas       bad            88       100     83          99
# 11        Air-Walker       bad            50        85    100          85
# 16             Amazo       bad            75       100    100         100
# 17              Ammo       bad             1         1      1           1
# 21            Angela       bad             1         1      1           1
# 23         Annihilus       bad            75        80     47          56
# 26      Anti-Monitor       bad            88        90     38          90
# 27        Anti-Spawn       bad             1         1      1           1
# 29        Apocalypse       bad           100       100     33         100
# 35          Arclight       bad            38        63     23          42
# 49            Azazel       bad            50        11     47          95
# 52              Bane       bad            88        53     23          56
# 67            Beetle       bad             1         1      1           1
# 73           Big Man       bad            75        12     23          28
# 75     Billy Kincaid       bad             1         1      1           1
# 78          Bird-Man       bad             1         1      1           1
# 79       Bird-Man II       bad             1         1      1           1
# 83      Black Abbott       bad             1         1      1           1
# 84        Black Adam       bad            88       100     92         100
# 92       Black Mamba       bad            75        10     35          42
# 96          Blackout       bad            63        32     45          80
# 97         Blackwing       bad            38        10     35          32
# 103         Blizzard       bad             1         1      1           1
# 104       Blizzard I       bad             1         1      1           1
# 105      Blizzard II       bad            38        10     27          42
# 106             Blob       bad            10        83     23          95
# 107         Bloodaxe       bad            63        80     33          80
# 109      Bloodwraith       bad             1         1      1           1
# 115       Bomb Queen       bad             1         1      1           1
# ..               ...       ...           ...       ...    ...         ...
# 485         Scorpion       bad            50        52     60          85
# 493          Shocker       bad            63        10     23          70
# 501         Sinestro       bad            75        80     53          64
# 502            Siren       bad            38        10     12          14
# 503         Siren II       bad             1         1      1           1
# 504            Siryn       bad            38         8     47          28
# 508   Solomon Grundy       bad             9        93     13         100
# 515   Spider-Carnage       bad             1         1      1           1
# 521  Spider-Woman IV       bad             1         1      1           1
# 535   Superboy-Prime       bad            94       100    100         100
# 538      Swamp Thing       bad            88        80     23         100
# 539            Sylar       bad            75        10     12          28
# 542           Thanos       bad            88       100     17         100
# 553      Tiger Shark       bad            38        72     42          70
# 555         Tinkerer       bad           100        10     23          14
# 562         Two-Face       bad            88        10     12          14
# 564           Ultron       bad            88        83     42         100
# 565      Utgard-Loki       bad            50        80     23          84
# 569         Vanisher       bad            63        10     75          56
# 570            Venom       bad            75        57     65          84
# 571         Venom II       bad            50        57     47          70
# 572        Venom III       bad            63        73     35          90
# 576         Violator       bad             1         1      1           1
# 581          Vulture       bad            63        22     47          56
# 582           Walrus       bad            50        28      8          50
# 586             Warp       bad            38        10     23          28
# 590        Weapon XI       bad             1         1      1           1
# 593   Willis Stryker       bad            38        16     23          28
# 605      Yellow Claw       bad             1         1      1           1
# 610             Zoom       bad            50        10    100          28
#
#      Power  Combat  Total
# 4       55      95    436
# 5      100      56    526
# 11     100      40    460
# 16     100     100    575
# 17       0       1      5
# 21       0       1      5
# 23      59      64    381
# 26     100      90    496
# 27       0       1      5
# 29     100      60    493
# 35      52      70    288
# 49      87      80    370
# 52      51      95    366
# 67       0       1      5
# 73      19      70    227
# 75       0       1      5
# 78       0       1      5
# 79       0       1      5
# 83       0       1      5
# 84      89      56    525
# 92      78      65    305
# 96      38      65    323
# 97      20      56    191
# 103      0       1      5
# 104      0       1      5
# 105     47      56    220
# 106     26      72    309
# 107     84      84    424
# 109      0       1      5
# 115      0       1      5
# ..     ...     ...    ...
# 485     49      80    376
# 493     63      56    285
# 501    100      56    428
# 502     55      28    157
# 503      0       1      5
# 504     50      42    213
# 508     78      30    323
# 515      0       1      5
# 521      0       1      5
# 535    100      85    579
# 538     66      56    413
# 539     91      56    272
# 542    100      80    485
# 553     21      28    271
# 555     10      14    171
# 562      9      28    161
# 564    100      64    477
# 565     72      64    373
# 569     39      42    285
# 570     79      84    444
# 571     54      56    334
# 572     66      56    383
# 576      0       1      5
# 581     40      56    284
# 582     11      20    167
# 586     63      50    212
# 590      0       1      5
# 593     41      60    206
# 605      0       1      5
# 610     72      28    288
#
# [165 rows x 9 columns]

# %%
# 16. Show first five records of point 15

villains.head()
# Out:
#            Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 4   Abomination       bad            63        80     53          90     55
# 5       Abraxas       bad            88       100     83          99    100
# 11   Air-Walker       bad            50        85    100          85    100
# 16        Amazo       bad            75       100    100         100    100
# 17         Ammo       bad             1         1      1           1      0
#
#     Combat  Total
# 4       95    436
# 5       56    526
# 11      40    460
# 16     100    575
# 17       1      5

# %%
# 17. Show top five fastest super villains in terms of super speed

top5_fastest_villains = villains.nlargest(5,'Speed')
top5_fastest_villains
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 11       Air-Walker       bad            50        85    100          85
# 16            Amazo       bad            75       100    100         100
# 535  Superboy-Prime       bad            94       100    100         100
# 610            Zoom       bad            50        10    100          28
# 242     General Zod       bad            94       100     96         100
#
#      Power  Combat  Total
# 11     100      40    460
# 16     100     100    575
# 535    100      85    579
# 610     72      28    288
# 242     94      95    579

# %%
# 18. Top five super villains in terms of intelligence

top5_most_intelligent_villains = villains.nlargest(5,'Intelligence')
top5_most_intelligent_villains
# Out:
#                 Name Alignment  Intelligence  Strength  Speed  Durability  \
# 386  Mister Mxyzptlk       bad           113        10     12          14
# 29        Apocalypse       bad           100       100     33         100
# 122         Brainiac       bad           100        28     63          90
# 194      Doctor Doom       bad           100        32     20         100
# 315            Joker       bad           100        10     12          56
#
#      Power  Combat  Total
# 386    100      28    277
# 29     100      60    493
# 122     60      75    416
# 194     93      84    429
# 315     22      90    290

# %%
# 19. Show who is most dangerous super villain after calculating their total (top 5 only)

villains.nlargest(5,'Total')
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 242     General Zod       bad            94       100     96         100
# 535  Superboy-Prime       bad            94       100    100         100
# 16            Amazo       bad            75       100    100         100
# 203        Dormammu       bad            88        95     83         100
# 201        Doomsday       bad            88        80     67         120
#
#      Power  Combat  Total
# 242     94      95    579
# 535    100      85    579
# 16     100     100    575
# 203    100      80    546
# 201    100      90    545

# %%
# 20. Draw a histogram for speed of super heroes having fig size 10,5, 
#           provide speed in histogram for only good alignment super heroes, 
#           title should be "distribution of speed",
#           xlabel should be "speed"

good_superheroes['Speed'].hist( figsize = (10,5), color = 'red' )
plt.suptitle('Distribution of Speed')
plt.xlabel("Speed")
# Out:
# Text(0.5, 0, 'Speed')

# %%
# 21. Draw a histogram for combat of super villains having fig size 10,5,
        # provide combat in histogram for only bad alignment super heroes, 
        # title should be "distribution of combat",
        # xlabel should be "combat"

villains['Combat'].hist( figsize = (10,5), color = 'orange' )
plt.suptitle('Distribution of Combat')
plt.xlabel('Combat')
# Out:
# Text(0.5, 0, 'Combat')

# %%
#########################################################################################
# - Bonus: Can go beyond the scope and extract some different information on different  #
#          characters and their properties. Can draw some more plots and histograms.    #
#########################################################################################

# %%
# Show average stats of superheroes and villains and neutral characters

df[['Alignment', 'Power']].groupby('Alignment').mean()
df.groupby('Alignment').mean()
# Out:
#            Intelligence   Strength      Speed  Durability      Power  \
# Alignment
# bad           50.018182  34.363636  27.684848   46.284848  44.230303
# good          41.995370  26.638889  26.685185   39.293981  38.291667
# neutral       60.909091  45.727273  46.727273   75.545455  58.818182
#
#               Combat       Total
# Alignment
# bad        44.630303  247.212121
# good       42.085648  214.990741
# neutral    67.636364  355.363636

# %%
# Get the Percentage Difference of each superhero Power and the average superhero power.
        # Percentage Increase from AVG = ( (power - AVG) / AVG ) * 100

average_power = good_superheroes['Power'].mean()
print('Average power of all superheroes:', round(average_power, 2))

power_difference = good_superheroes.filter(['Name', 'Power'], axis=1)
power_difference = power_difference.assign( Power_Difference = 
                                               lambda x: (( (x.Power - average_power) / average_power) * 100)
                                                       .round(2)
#                                                            .astype(str) + "%"
                                          ) 



power_difference
# Out:
# Average power of all superheroes: 38.29
#                   Name  Power  Power_Difference
# 0              3-D Man     25            -34.71
# 1               A-Bomb     17            -55.60
# 2           Abe Sapien     35             -8.60
# 3             Abin Sur     84            119.37
# 6          Adam Monroe     71             85.42
# 7         Adam Strange      0           -100.00
# 8            Agent  13      0           -100.00
# 9            Agent Bob      5            -86.94
# 10          Agent Zero     72             88.03
# 12          Alan Scott     98            155.93
# 13        Alex Woolsly      0           -100.00
# 14   Alfred Pennyworth      7            -81.72
# 15    Allan Quatermain      0           -100.00
# 18      Ando Masahashi      0           -100.00
# 19               Angel     17            -55.60
# 20     Angel Salvadore     46             20.13
# 22          Animal Man     73             90.64
# 24             Ant-Man     32            -16.43
# 25          Ant-Man II     32            -16.43
# 30            Aquababy     37             -3.37
# 31             Aqualad     76             98.48
# 32             Aquaman     65             69.75
# 33             Arachne      0           -100.00
# 34           Archangel     28            -26.88
# 36                Ares     62             61.92
# 37               Ariel     72             88.03
# 38               Armor     55             43.63
# 39             Arsenal      0           -100.00
# 40           Astro Boy      0           -100.00
# 41               Atlas     69             80.20
# ..                 ...    ...               ...
# 573         Vertigo II      0           -100.00
# 574         Vindicator      0           -100.00
# 575      Vindicator II     56             46.25
# 577             Violet     65             69.75
# 578             Vision     76             98.48
# 579          Vision II      0           -100.00
# 580             Vulcan      0           -100.00
# 583        War Machine    100            161.15
# 584            Warbird      0           -100.00
# 585            Warlock     71             85.42
# 587            Warpath     26            -32.10
# 588               Wasp     23            -39.93
# 589            Watcher    100            161.15
# 591        White Queen      0           -100.00
# 592           Wildfire     77            101.09
# 594     Winter Soldier     60             56.69
# 595            Wiz Kid      0           -100.00
# 596          Wolfsbane     26            -32.10
# 597          Wolverine     44             14.91
# 598        Wonder Girl     39              1.85
# 599         Wonder Man     64             67.14
# 600       Wonder Woman     42              9.68
# 601             Wondra      0           -100.00
# 602     Wyatt Wingfoot      1            -97.39
# 603               X-23     27            -29.49
# 604              X-Man     92            140.26
# 606       Yellowjacket     12            -68.66
# 607    Yellowjacket II     31            -19.04
# 608               Ymir     83            116.76
# 609            Zatanna    100            161.15
#
# [432 rows x 3 columns]

# %%
# Retrieve mean deviation for the Power column and plotted it on a histogram
mean_deviation_power = power_difference['Power_Difference'].hist( figsize = (10,5) )
plt.suptitle('Mean Deviation of Power')
plt.xlabel('Power')
# Out:
# Text(0.5, 0, 'Power')

# %%
characters_average_stats = df.loc[:, df.columns != 'Total'].groupby('Alignment').mean().plot(figsize = (10,5))

plt.yticks(np.arange(0, 80, 5))

characters_average_stats
